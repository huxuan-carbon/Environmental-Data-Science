# %%
x=2
y=3
x,y=y,x
print(x,y)
# Out:
# 3 2

# %%
print("Let's go!")
# Out:
# Let's go!

# %%
print("\"Life is short,let's learn Python.\"")
# Out:
# "Life is short,let's learn Python."

# %%
print("I love learn\nI'm happy")
# Out:
# I love learn
# I'm happy

# %%
print("D:\\three\\two\\one\\go")
# Out:
# D:\three\two\one\go

# %%
520+1314
# Out:
# 1834

# %%
"520"+"1314"
# Out:
# '5201314'

# %%
'520'+'1314'
# Out:
# '5201314'

# %%
print("I love yuo"*3)
# Out:
# I love yuoI love yuoI love yuo

# %%
x=3
print(int(x))
# Out:
# 3

# %%
x=3.2
print(float(x))
# Out:
# 3.2

# %%
x="hello"
print(str(x))
# Out:
# hello

# %%
x=True
print(bool(x))
# Out:
# True

# %%
print("我的名字是""年龄是")
# Out:
# 我的名字是年龄是

# %%
print("今天气温",26,"度")
# Out:
# 今天气温 26 度

# %%
print("今天气温"+"26"+"度")
# Out:
# 今天气温26度

# %%
x=26
print(f"今天气温{x}度")
# Out:
# 今天气温26度

# %%
name=input("你的名字：")
print(f"hello!{name}")
# Out:
# 你的名字： 胡先生
# hello!胡先生

# %%
height=input("你的身高：")
weight=input("你的体重:")
height=float(height)
weight=float(weight)
bmi=weight/height**2
print(f"你的BMI是{bmi:.2f}")
# Out:
# 你的身高： 1.65
# 你的体重: 65
# 你的BMI是23.88

# %%
electricity=float(input("请输入年用电量（度）："))
factor=0.785
carbon=electricity*factor
print(f"你一年用电所排放的二氧化碳为{carbon:.2f}千克")
# Out:
# 请输入年用电量（度）： 100
# 你一年用电所排放的二氧化碳为78.50千克
