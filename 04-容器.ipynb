# %%
passengers=[120,85,200,60,150]
print(passengers[0])
# Out:
# 120

# %%
print(passengers[-1])
# Out:
# 150

# %%
passengers[0:3]
# Out:
# [120, 85, 200]

# %%
passengers[:2]
# Out:
# [120, 85]

# %%
passengers.append(999)

# %%
nums=[10,20,30]
nums.append(999)
print(nums)
# Out:
# [10, 20, 30, 999]

# %%
nums.insert(0,5)
print(nums)
# Out:
# [5, 10, 20, 30, 999]

# %%
nums[1]=17
print(nums)
# Out:
# [5, 17, 20, 30, 999]

# %%
nums.pop()
# Out:
# 999

# %%
if 30 in nums:
    nums.remove(30)
else:
    print("列表中没有30")
print(nums)
# Out:
# [5, 17, 20]

# %%
total=0
for p in passengers:
    total=total+p
print("总客流=",total)
big=[p for p in passengers if p>100]
# Out:
# 总客流= 5610

# %%
print(big)
# Out:
# [120, 200, 150, 999, 999, 999, 999, 999]

# %%
big.remove(999)
print(big)
# Out:
# [120, 200, 150, 999, 999, 999]

# %%
while 999 in big:
    big.remove(999)
print(big)
# Out:
# [120, 200, 150]

# %%
point=(3,5)
x,y=point

# %%
point[0]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 point[0]=10
#
# TypeError: 'tuple' object does not support item assignment

# %%
station={
    "name":"西直门",
    "lines":["2号线","4号线"],
    "daily_passengers":350000
}

# %%
station["name"]
# Out:
# '西直门'

# %%
station.get("phone","暂无")
# Out:
# '暂无'

# %%
station["open_year"]=1896

# %%
del station["daily_passengers"]

# %%
print(station)
# Out:
# {'name': '西直门', 'lines': ['2号线', '4号线'], 'open_year': 1896}

# %%
names=["西直门","国贸","西直门","国贸","国贸"]
counter={}
for name in names:
    counter[name]=counter.get(name,0)+1
print(counter)
# Out:
# {'西直门': 2, '国贸': 3}

# %%
network={"2号线":{"stations":["西直门","积水潭"],"color":"blue"}}
print(network["2号线"]["color"])
# Out:
# blue

# %%
print(network["2号线"]["stations"][1])
# Out:
# 积水潭

# %%
rows=[{"station":"西直门","in":120},{"station":"国贸","in":200}]
print(rows[1]["in"])
# Out:
# 200

# %%
in_flow=[120,85,200,60,150]
total_in=sum(in_flow)
max_in=max(in_flow)
print("总进站量=",total_in)
print("最高时段=",max_in)
# Out:
# 总进站量= 615
# 最高时段= 200

# %%
names=["2号线","1号线","4号线","2号线","1号线","2号线"]
counter={}
for name in names:
    counter[name]=counter.get(name,0)+1
print(counter)
# Out:
# {'2号线': 3, '1号线': 2, '4号线': 1}

# %%
stations=[{"name":"西直门","passengers":35000},{"name":"国贸","passengers":28000}]
for s in stations:
    print(s["name"])
# Out:
# 西直门
# 国贸
