# %%
26+38.8+42+37+58+69.8+49.8+49.8+37.8
# Out:
# 409.00000000000006

# %%
station="北京西站"
line="九号线"
print(station,line)
# Out:
# 北京西站 九号线

# %%
station="北京"+"西站"
line="-"*10
print(station,line)
# Out:
# 北京西站 ----------

# %%
print("I love learing\nI love school")
# Out:
# I love learing
# I love school

# %%
print("西站\t客流")
# Out:
# 西站	客流

# %%
print("C:\\Users\\x")
# Out:
# C:\Users\x

# %%
print('Let\'s go')
# Out:
# Let's go

# %%
print("你好:\"我叫xxx\"")
# Out:
# 你好:"我叫xxx"

# %%
print(r"C:\Users\Desktop\data.csv")
# Out:
# C:\Users\Desktop\data.csv

# %%
station="北京西站"
passengers=1000
print(f"{station}的日客流量是{passengers}人")
# Out:
# 北京西站的日客流量是1000人

# %%
station="北京西站"
passengers=1000
print("station的日课流量是passengers人")
# Out:
# station的日课流量是passengers人

# %%
station="北京西站"
passengers=1000
print(station,"的日课流量是",passengers,"人")
# Out:
# 北京西站 的日课流量是 1000 人

# %%
avg=1234.5678
print(f"平均客流量为{avg:.2f}")
print(f"百分比为{0.1234:.1%}")
# Out:
# 平均客流量为1234.57
# 百分比为12.3%

# %%
s="北京西站"
print(s[0])
# Out:
# 北

# %%
s="北京西站"
print(s[-1])
# Out:
# 站

# %%
s="北京西站"
print(s[1:2])
# Out:
# 京

# %%
s="北京西站"
print(s[:2])
# Out:
# 北京

# %%
s="北京西站"
print(s[2:])
# Out:
# 西站

# %%
name="beijing west"
print(name.upper())
# Out:
# BEIJING WEST

# %%
name="beijing west"
print(name.lower())
# Out:
# beijing west

# %%
name="beijing west"
print(name.title())
# Out:
# Beijing West

# %%
s="   北京西站    "
print(s.strip())
# Out:
# 北京西站

# %%
s="   北京西站    "
print(s.lstrip())
# Out:
# 北京西站

# %%
s="   北京西站    "
print(s.rstrip())
# Out:
#    北京西站

# %%
line="九  号  线"
clean=line.replace(" ","")
print(clean)
# Out:
# 九号线

# %%
data="北京西，丰台，大兴"
stations=data.split(",")
print(stations)
# Out:
# ['北京西，丰台，大兴']

# %%
new_data="|".join(stations)
print(new_data)
# Out:
# 北京西，丰台，大兴

# %%
s="Beijing South Railway Station"
print(s.find("South"))
# Out:
# 8

# %%
print("South" in s)
# Out:
# True

# %%
print(s.startswith("Bei"))
# Out:
# True

# %%
print(s.endswith("Station"))
# Out:
# True

# %%
print(len(s))
# Out:
# 29

# %%
raw="北京西站；日客流量= 95632 人；9号线"
parts=raw.split("；")
station=parts[0].strip()
line=parts[2].strip()
flow_part=parts[1]
flow_str=flow_part.split("=")[1]
flow_str=flow_str.replace("人","").strip()
flow=int(flow_str)
print(f"线路：{line}|站点：{station}|日客流：{flow:,}人")
# Out:
# 线路：9号线|站点：北京西站|日客流：95,632人

# %%
x="hello world"
print(x.title())
# Out:
# Hello World

# %%
print(x.upper())
# Out:
# HELLO WORLD

# %%
print(x.lower())
# Out:
# hello world

# %%
data="apple,banana,cherry"
parts=data.split(",")
two=parts[1].strip()
print(two)
# Out:
# banana

# %%
station="西直门"
line="二号线"
flow=int(85632)
x=0.125
print(f"站点：{station},编号：{line},客流：{flow:,}人，占比{x:.1%}")
# Out:
# 站点：西直门,编号：二号线,客流：85,632人，占比12.5%

# %%
station="  北京南站  "
print(station.strip())
# Out:
# 北京南站

# %%
print(station.startswith("北京"))
# Out:
# False
